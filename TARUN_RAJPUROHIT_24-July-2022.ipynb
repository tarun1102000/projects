# %% [markdown]
# <font color='blue'>
#     <font size = 5>
#         You have been given the role of a business analyst for an E-Commerce company and have been asked to prepare a basic report on the data. Follow the steps below for preparation of the report.
#
# Before you start analysing the data, it is always a good practice to see the size of the data, its features and feature types. If the data set is big, it is not possible to print out all the records.
#     </font>
# ####  Note: Use the markdown feature of Python to explain your answer.

# %% [markdown]
# ## Load the necessary libraries. Import and load the dataset with a name ECom_Data .

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
pd.options.display.max_rows = 10

# %%
# Get the Data

ECom_Data=pd.read_csv('F:\Personal\PGP\Python for Data Science\E-Commerce_Flipkart.csv')

# %% [markdown]
# <font color='blue'>
#     <font size = 5>
#         We have read the data and stored the data in "ECom_Data" variable </font>

# %% [markdown]
# ## Q 1.	To get familiar with the data
# ## a)	Print out the first 10 and the last 10 records of the data. (2 marks)
# ## b)	How many rows and columns are present in the dataset? Use any two different methods to extract this information. (2 + 2 + 1 marks)
# ## c)	How many object data types are there? (1 mark)
# ## d)	Is there any Boolean data type? (1 mark)
# #### Note: Use the markdown feature of Python to explain your answer.

# %% [markdown]
# #### Ans 1 a)

# %%
ECom_Data.head(10)
# Out:
#                    Customer_uniq_id Region  Order_Date Expected_Delivery_Date  \
# 0  c2d766ca982eca8304150849735ffef9  North  31-12-2021             03-01-2022
# 1  7f7036a6d550aaa89d34c77bd39a5e48  East   31-12-2021             03-01-2022
# 2  f449ec65dcbc041b6ae5e6a32717d01b  East   31-12-2021             03-01-2022
# 3  0973b37acd0c664e3de26e97e5571454   West  31-12-2021             03-01-2022
# 4  bc940ea42ee6bef5ac7cea3fb5cfbee7   West  31-12-2021             03-01-2022
# 5  ce5a6818f7707e2cb61fdcdbba61f5ad  East   25-12-2021             28-12-2021
# 6  8542703ca9e6ebdf6d742638dfb1f2ca  East   25-12-2021             28-12-2021
# 7  29c8d290caa451f97b1c32df64477a2c  North  25-12-2021             28-12-2021
# 8  4044c0ac52c1ee4b28777417651faf42  East   25-12-2021             28-12-2021
# 9  e54bc0a7c3429da2ebef0b30331fe3d2  East   25-12-2021             28-12-2021
#
#   Delivered_Date                                       product_name  \
# ...

# %%
ECom_Data.tail(10)
# Out:
#                       Customer_uniq_id Region  Order_Date  \
# 8917  4db03bc4ccbe216cf151b2f2b904ba3f  East   01-12-2020
# 8918  4d4d6aeb13fa253499d0dd45a5abd87e   West  01-12-2020
# 8919  ea19e7ef703293d3f6c799ca9db4642d   West  01-12-2020
# 8920  19a53a958992fb575acffb5d41e7ef9e  East   01-12-2020
# 8921  09abab80c8dfdc6f268e0a6f05a0be11  North  01-12-2020
# 8922  90d30478255e23621e8929ed15c2f6e4  South  01-12-2020
# 8923  20a73e3f41490a73ceeba5f17658db8f   West  01-12-2020
# 8924  5c1554cd45f9d538c2c6947dbdd59c75  East   01-12-2020
# 8925  6b737a4deca1ed0e56c179e66036e994   West  01-12-2020
# 8926  a5235ac28d3d5487f54025f9d6b57433  North  01-12-2020
#
#      Expected_Delivery_Date Delivered_Date  \
# 8917             04-12-2020     04-12-2020
# 8918             04-12-2020     04-12-2020
# 8919             04-12-2020     04-12-2020
# 8920             04-12-2020     04-12-2020
# 8921             04-12-2020     04-12-2020
# 8922             04-12-2020     04-12-2020
# ...

# %% [markdown]
# #### Ans 1 b)

# %% [markdown]
# There are 8927 rows and 17 columns in this dataset.

# %%
ECom_Data
# Out:
#                       Customer_uniq_id Region  Order_Date  \
# 0     c2d766ca982eca8304150849735ffef9  North  31-12-2021
# 1     7f7036a6d550aaa89d34c77bd39a5e48  East   31-12-2021
# 2     f449ec65dcbc041b6ae5e6a32717d01b  East   31-12-2021
# 3     0973b37acd0c664e3de26e97e5571454   West  31-12-2021
# 4     bc940ea42ee6bef5ac7cea3fb5cfbee7   West  31-12-2021
# ...                                ...    ...         ...
# 8922  90d30478255e23621e8929ed15c2f6e4  South  01-12-2020
# 8923  20a73e3f41490a73ceeba5f17658db8f   West  01-12-2020
# 8924  5c1554cd45f9d538c2c6947dbdd59c75  East   01-12-2020
# 8925  6b737a4deca1ed0e56c179e66036e994   West  01-12-2020
# 8926  a5235ac28d3d5487f54025f9d6b57433  North  01-12-2020
#
#      Expected_Delivery_Date Delivered_Date  \
# 0                03-01-2022     02-01-2022
# 1                03-01-2022     02-01-2022
# 2                03-01-2022     02-01-2022
# 3                03-01-2022     02-01-2022
# 4                03-01-2022     02-01-2022
# ...

# %% [markdown]
# When we load the dataset, which is ECom_Data in this case, python by default prints first and last 5 rows of the dataset. Besides, at the end of the output in the bottom left corner we see 8927 rows x 17 columns. Hence, it denotes that the dataset has 8927 rows and 17 columns.

# %%
print(len(ECom_Data))
print(len(ECom_Data.columns))
# Out:
# 8927
# 17

# %% [markdown]
# The len function in python is responsible for identifying the number of items in an object, which is the table in this case. Hence, we get the number of rows as 8927. Whereas, if we specify, what we want from python to count within that object, just like here I desired for columns,i.e., ECom_Data.columns. Hence, the number of columns is 17. Therefore, this dataset has 8927 rows and 17 columns.

# %% [markdown]
# #### Ans  1 c)

# %%
ECom_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8927 entries, 0 to 8926
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Customer_uniq_id            8927 non-null   object
#  1   Region                      8927 non-null   object
#  2   Order_Date                  8927 non-null   object
#  3   Expected_Delivery_Date      8927 non-null   object
#  4   Delivered_Date              8927 non-null   object
#  5   product_name                8927 non-null   object
#  6   product_main_category       8927 non-null   object
#  7   product_subcategory         8927 non-null   object
#  8   product_category_filter     8927 non-null   object
#  9   product_category_subfilter  8927 non-null   object
#  10  product_unique ID           8927 non-null   object
#  11  retail_price                8927 non-null   int64
#  12  discounted_price            8927 non-null   int64
# ...

# %% [markdown]
# The info function of the python, enlists all the data types existing from the loaded dataset. Therefore, from the output we can clearly figure out that the loaded dataset as 14 object data types.

# %% [markdown]
# ### Ans 1 d)

# %%
ECom_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8927 entries, 0 to 8926
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Customer_uniq_id            8927 non-null   object
#  1   Region                      8927 non-null   object
#  2   Order_Date                  8927 non-null   object
#  3   Expected_Delivery_Date      8927 non-null   object
#  4   Delivered_Date              8927 non-null   object
#  5   product_name                8927 non-null   object
#  6   product_main_category       8927 non-null   object
#  7   product_subcategory         8927 non-null   object
#  8   product_category_filter     8927 non-null   object
#  9   product_category_subfilter  8927 non-null   object
#  10  product_unique ID           8927 non-null   object
#  11  retail_price                8927 non-null   int64
#  12  discounted_price            8927 non-null   int64
# ...

# %% [markdown]
# Once again using the info function of python, we can figure out that the only available data types existing in the dataset is float, integer and object. Hence, there's no boolean data type in the loaded dataset.

# %% [markdown]
# <font color='blue'>
#     <font size = 5>
#  Once you are familiar with the data, you may decide that not all features are of use to you and you may want to delete the non-informative features (columns)</font>

# %% [markdown]
# ## Q 2.	Eliminating the non-informative columns.
# ## a)	Drop the columns product_specifications and description. (2 marks)
# ## b)	Which method or function is used to permanently delete the columns mentioned in part (a)? Write the code explicitly (2 marks)
# ### Note: Use the markdown feature of Python to explain your answer.

# %% [markdown]
# ### Ans 2 a)

# %%
ECom_Data.drop(['product_specifications','description'],axis = 1, inplace = True)

# %% [markdown]
# ### Ans 2 b)

# %% [markdown]
# ECom_Data.drop(['product_specifications','description'],axis = 1, inplace = True)
#
# The drop function is used to delete the columns of our choice. The axis = 1 is responsible for deleting columns as opposed to axis = 0, which is responsible for deleting rows. The dropping of columns is a temporary method in python by default. Whereas, with the help of inplace = True function we can permanently delete our desired row/column from the dataset.

# %% [markdown]
# <font color='blue'>
#     <font size = 5>
#         The next steps in this project involves summarization of data at various levels and visualization. Apparently, such simple steps are very useful to get an overall sense of the data.
#     </font>

# %% [markdown]
# ## Q 3. Here we summarize the data at Brand level.
# ## a) How many unique Brand are there? (1 mark)
# ## b) Note that each Brand contains multiple products. Show the average product_rating within each Brand (2 marks)

# %% [markdown]
# ### Ans 3 a)

# %%
n = len(pd.unique(ECom_Data['Brand']))  
print("No. of unique brands :", n)
# Out:
# No. of unique brands : 2580

# %% [markdown]
# No. of unique brands : 2580
#
# The pd.unique finds the unique brands from the dataset and the len function turns these unique brands into numbers. Hence, we have 2580 unique brands in this dataset.

# %% [markdown]
# ### Ans 3 b)

# %%
ECom_Data.groupby('Brand').product_rating.mean()
# Out:
# Brand
# 1OAK            1.500000
# 3A AUTOCARE     3.268293
# 3D Mat          3.000000
# 3kFactory       2.000000
# 4D              3.600000
#                   ...
# youniqueshop    2.000000
# zDelhi.com      5.000000
# zaidis          4.000000
# zasmina         4.500000
#  Tarkan         5.000000
# Name: product_rating, Length: 2580, dtype: float64

# %% [markdown]
# ## Q 4. Next we study the main categories of the products.
#
# ## a) Create an appropriate plot to show the count of items ordered for each product_main_category. (5 marks).
#
# ### Hint: Create a bar chart titled "Product Category type" where product_main_category are on x-axis and counts are on y-axis.
#
# ### Note: Both axis labels, i.e. the names of the product_main_category and counts must be clearly legible.
#
# ## b) From the plot identify for which two product_main_category(s)  maximum and minimum orders were placed. (2 marks)
#
# ## c) Write code to print out the top 5 product_main_category(s)  in descending order? (2 marks)

# %% [markdown]
# ### Ans 4 a)

# %%
plt.figure(figsize=(20,20))
sns.countplot(data=ECom_Data, x ='product_main_category')
plt.xticks(rotation=90);

# %% [markdown]
# ### Ans 4 b)

# %% [markdown]
# From the bargraph we can identify that the maximum orders were placed in clothing category and the minimum orders were placed in Wearable Smart Devices.

# %% [markdown]
# ### Ans 4 c)

# %%
ECom_Data.product_main_category.value_counts().head()
# Out:
# Clothing                       2952
# Mobiles & Accessories          1084
# Automotive                     1001
# Home Decor & Festive Needs      727
# Computers                       558
# Name: product_main_category, dtype: int64

# %% [markdown]
# <font color='blue'>
#     <font size = 5>
#     In E-commerce, both the retailers (here brands) and the company have to make profit to sustain in the business.
#     The E-Commerce company has the following rule for computing their own revenue: </font>
#
# ####     The company charges
# ####  (i) 25% on the orders having final price (discounted price) greater than 600
#
# #### (ii) 15% on the orders having final price (discounted price) greater than 350 but less than or equal to 600
#
# #### (iii) 10% on the orders having final price (discounted price) greater than 100 but less than or equal to 350
#
# #### (iv) Otherwise, 5% on the final price (discounted price)    </font>

# %% [markdown]
# ## Q 5. Find the net revenue generated by the E-Commerce company over all orders placed. (6 marks)

# %% [markdown]
# ### Ans 5

# %%
Net_Revenue = []
for i in ECom_Data['discounted_price']:
  if i > 600:
    Net_Revenue_Value = i*0.25
    Net_Revenue.append(Net_Revenue_Value)
  elif i > 350 <= 600:
    Net_Revenue_Value = i*0.15
    Net_Revenue.append(Net_Revenue_Value)
  elif i > 100 <= 350:
    Net_Revenue_Value = i*0.10
    Net_Revenue.append(Net_Revenue_Value)
  else:
    Net_Revenue_Value = i*0.05
    Net_Revenue.append(Net_Revenue_Value)

ECom_Data['Net_Revenue_']=np.array(Net_Revenue)

print('The net revenue generated by the E-Commerce company over all orders placed:', ECom_Data['Net_Revenue_'].sum())
# Out:
# The net revenue generated by the E-Commerce company over all orders placed: 2242221.75

# %% [markdown]
# <font color='blue'>
#     <font size = 5>
#     Now you need to find the revenue for each retailer (Brand)
#     </font>

# %% [markdown]
# ## Q6.Calculate the Net BrandRevenue for each Brand and list the top 14 Brand having maximum revenue in descending order (5 marks)
# #### Hint: Net BrandRevenue is BrandRevenue which is generated after all the deductions. Also, BrandRevenue is different from the E-Commerce company's net revenue.

# %% [markdown]
# ### Ans 6

# %%
Brand_Revenue = ECom_Data['discounted_price'] - ECom_Data['Net_Revenue_']
ECom_Data['Net_Brand_Revenue_'] = np.array(Brand_Revenue)

# %%
Top_14_Brands = ECom_Data.groupby('Brand').Net_Brand_Revenue_.sum()
Top_14_Brands.head(14)
# Out:
# Brand
# 1OAK                1015.40
# 3A AUTOCARE        55647.90
# 3D Mat              5249.25
# 3kFactory            156.60
# 4D                  5961.00
#                      ...
# 99Gems               313.20
# @home              16828.50
# A A STORE           2036.60
# A R ENTERPRISES      269.10
# A To Z Traders       749.25
# Name: Net_Brand_Revenue_, Length: 14, dtype: float64

# %% [markdown]
# <font color='blue'>
#     <font size = 5>
# Let us now investigate multiple features for each product to determine any pattern.
# </font>

# %% [markdown]
# ## Q 7. Compare prices of the products.
#
# ## a)	Draw boxplots of retail_price & discounted_price. (2 marks)
#
# ## b)	 Are there any outliers? (Yes/No) (1mark)
#
# ## c)	Create a scatterplot of retail_price (x-axis) and discounted_price (y-axis) (2 marks)

# %% [markdown]
# ### Ans 7 a)

# %%
plt.figure(figsize=(20,10))
plt.xlim(0,8000)
sns.boxplot(data=ECom_Data,x='retail_price');

# %%
plt.figure(figsize=(20,10))
plt.xlim(0,6000)
sns.boxplot(data=ECom_Data,x='discounted_price');

# %% [markdown]
# ### Ans 7 b)

# %% [markdown]
# Yes, there are outliers in the boxplot of retail price & discounted price.

# %% [markdown]
# ### Ans 7 c)

# %%
sns.scatterplot(data=ECom_Data,x='retail_price',y='discounted_price');

# %% [markdown]
# <font color='blue'>
#     <font size = 5>
#     The next steps will enable to study brand-level information.
#     </font>

# %% [markdown]
# ## Q 8. Create a new dataframe to include the Brand specific information as stated:
# ## i.	total number of orders placed per Brand
# ## ii.	total retail_price per Brand
# ## iii.	total discounted_price per Brand, and
# ## iv.	total net BrandRevenue generated per Brand.
#
# ## Also, draw a pairplot using these four features. (3 marks)

# %% [markdown]
# ### Ans 8

# %%
revenue = ECom_Data.groupby(by='Brand').sum()

# %%
no_of_orders = ECom_Data.groupby(by='Brand').Customer_uniq_id.count()
revenue['no_of_orders'] = no_of_orders

# %%
revenue
# Out:
#               retail_price  discounted_price  product_rating  Net_Revenue_  \
# Brand
# 1OAK                  1698              1274             3.0        258.60
# 3A AUTOCARE         107059             74134           134.0      18486.10
# 3D Mat                7250              6999             3.0       1749.75
# 3kFactory              399               174             2.0         17.40
# 4D                   17500              7948            18.0       1987.00
# ...                    ...               ...             ...           ...
# youniqueshop           810               640             2.0        160.00
# zDelhi.com            4499              3999             5.0        999.75
# zaidis                 150               129             4.0         12.90
# zasmina               1400               639             9.0         63.90
#  Tarkan               1999               349             5.0         34.90
#
#               Net_Brand_Revenue_  no_of_orders
# Brand
# ...

# %%
revenue.drop(['product_rating','Net_Revenue_'],axis = 1, inplace = True)

# %%
revenue = revenue[['no_of_orders','retail_price','discounted_price','Net_Brand_Revenue_']]

# %%
sns.pairplot(data=revenue[['no_of_orders','retail_price','discounted_price','Net_Brand_Revenue_']]);

# %% [markdown]
# <font color='blue'>
#     <font size = 5>
#     The E-Commerce company operate in multiple regions. It is important to understand its performance in each region.
#     </font>

# %% [markdown]
# ## Q 9.Compare performance regionwise
#
# ## a)	Draw a lineplot for the monthly net Revenue of E-Commerce Company for each region separately.  (4 marks)
#
# ## b)	Identify the best and the worst performing months for each region. (2 marks)
#
# #### Note: Only those days with actual orders(Order_Date) placed are present in the dataset. Assuming there were no orders on other days

# %% [markdown]
# ### Ans 9 a)

# %%
ECom_Data['Order_Date'] = pd.to_datetime(ECom_Data['Order_Date'],dayfirst=True)
ECom_Data['Order_Date'].dt.strftime('%d-%m-%Y')
# Out:
# 0       31-12-2021
# 1       31-12-2021
# 2       31-12-2021
# 3       31-12-2021
# 4       31-12-2021
#            ...
# 8922    01-12-2020
# 8923    01-12-2020
# 8924    01-12-2020
# 8925    01-12-2020
# 8926    01-12-2020
# Name: Order_Date, Length: 8927, dtype: object

# %%
Months = ECom_Data['Order_Date'].dt.month
ECom_Data['Order_Month'] = Months

# %%
North = ECom_Data.query("Region == 'North'")
sns.lineplot(data=North, x="Order_Month", y="Net_Revenue_",ci=False);

# %%
South = ECom_Data.query("Region == 'South'")
sns.lineplot(data=South, x="Order_Month", y="Net_Revenue_",ci=False);

# %%
West = ECom_Data.query("Region == 'West'")
sns.lineplot(data=West, x="Order_Month", y="Net_Revenue_",ci=False);

# %%
East = ECom_Data.query("Region == 'East '")
sns.lineplot(data=East, x="Order_Month", y="Net_Revenue_",ci=False);

# %% [markdown]
# I'm not sure, why the code for East Region is not working(wherein there's no error to the code), when it is working for other regions, and also in the combined Region plot below, we could see the plotting for east region.

# %%
plt.figure(figsize=(7,7))
plt.xlabel('Month')
plt.ylabel('Net Revenue')
sns.lineplot(data=ECom_Data,x='Order_Month',y='Net_Revenue_',hue='Region',ci=False);

# %% [markdown]
# ### Ans 9 b)

# %% [markdown]
# The best performing months as per the following regions are:
#
# North = 8 (August),
# South = 3 (March),
# West = 3 (March),
# East = 8 (August).
#
# The worst performing months as per the following regions are:
#
# North = 7 (July),
# South = 5 (May),
# West = 10 (October),
# East = 10 (October).

# %% [markdown]
# <font color='blue'>
#     <font size = 5>
#     Congratulations! You have learnt how to approach a complex data and extract information out of it.
#     </font>
