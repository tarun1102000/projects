# %% [markdown]
# # PROBLEM 1

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
auto = pd.read_csv(r'C:\Users\ABC\Downloads\austo_automobile+(2)+(1) (1).csv')

# %%
auto
# Out:
#       Age  Gender Profession Marital_status      Education  No_of_Dependents  \
# 0      53    Male   Business        Married  Post Graduate                 4
# 1      53   Femal   Salaried        Married  Post Graduate                 4
# 2      53  Female   Salaried        Married  Post Graduate                 3
# 3      53  Female   Salaried        Married       Graduate                 2
# 4      53    Male   Salaried        Married  Post Graduate                 3
# ...   ...     ...        ...            ...            ...               ...
# 1576   22    Male   Salaried         Single       Graduate                 2
# 1577   22    Male   Business        Married       Graduate                 4
# 1578   22    Male   Business         Single       Graduate                 2
# 1579   22    Male   Business        Married       Graduate                 3
# 1580   22    Male   Salaried        Married       Graduate                 4
#
# ...

# %%
auto.shape
# Out:
# (1581, 14)

# %%
auto.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1581 entries, 0 to 1580
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Age               1581 non-null   int64
#  1   Gender            1528 non-null   object
#  2   Profession        1581 non-null   object
#  3   Marital_status    1581 non-null   object
#  4   Education         1581 non-null   object
#  5   No_of_Dependents  1581 non-null   int64
#  6   Personal_loan     1581 non-null   object
#  7   House_loan        1581 non-null   object
#  8   Partner_working   1581 non-null   object
#  9   Salary            1581 non-null   int64
#  10  Partner_salary    1475 non-null   float64
#  11  Total_salary      1581 non-null   int64
#  12  Price             1581 non-null   int64
#  13  Make              1581 non-null   object
# dtypes: float64(1), int64(5), object(8)
# memory usage: 173.0+ KB

# %%
auto.isnull().sum()
# Out:
# Age                   0
# Gender               53
# Profession            0
# Marital_status        0
# Education             0
# No_of_Dependents      0
# Personal_loan         0
# House_loan            0
# Partner_working       0
# Salary                0
# Partner_salary      106
# Total_salary          0
# Price                 0
# Make                  0
# dtype: int64

# %%
auto['Partner_salary'] = auto['Total_salary'] - auto['Salary']

# %%
auto.isnull().sum()
# Out:
# Age                  0
# Gender              53
# Profession           0
# Marital_status       0
# Education            0
# No_of_Dependents     0
# Personal_loan        0
# House_loan           0
# Partner_working      0
# Salary               0
# Partner_salary       0
# Total_salary         0
# Price                0
# Make                 0
# dtype: int64

# %%
auto['Gender'].replace('Femal','Female',inplace=True)

# %%
auto['Gender'].replace('Femle','Female',inplace=True)

# %%
plt.figure(figsize=(15,5))
sns.countplot(data=auto,x='Age');

# %%
plt.figure(figsize=(10,5))
sns.countplot(data=auto,x='Gender');

# %%
plt.figure(figsize=(10,5))
sns.countplot(data=auto,x='Marital_status');

# %%
plt.figure(figsize=(10,5))
sns.countplot(data=auto,x='Profession');

# %%
plt.figure(figsize=(10,5))
sns.countplot(data=auto,x='Education');

# %%
plt.figure(figsize=(10,5))
sns.countplot(data=auto,x='No_of_Dependents');

# %%
plt.figure(figsize=(10,5))
sns.countplot(data=auto,x='Personal_loan');

# %%
plt.figure(figsize=(10,5))
sns.countplot(data=auto,x='House_loan');

# %%
plt.figure(figsize=(10,5))
sns.countplot(data=auto,x='Partner_working');

# %%
plt.figure(figsize=(10,5))
sns.countplot(data=auto,x='Make');

# %%
plt.figure(figsize=(10,5))
sns.histplot(data=auto,x='Salary',bins=14);

# %%
plt.figure(figsize=(10,5))
sns.histplot(data=auto,x='Partner_salary',bins=4);

# %%
plt.figure(figsize=(10,5))
sns.histplot(data=auto,x='Total_salary',bins=10,binwidth=10000);

# %%
plt.figure(figsize=(10,5))
sns.histplot(data=auto,x='Price',binwidth=2000);

# %%
sns.pairplot(data=auto[['Age','Gender','Profession', 'Marital_status','Education','No_of_Dependents','Personal_loan',	'House_loan',	'Partner_working',	'Salary',	'Partner_salary',	'Total_salary','Price', 'Make']])

# %%
sns.heatmap(data=auto[['No_of_Dependents','Salary','Partner_salary','Total_salary','Price']].corr(), annot = True);

# %%
plt.figure(figsize=(10,5))
sns.swarmplot(data=auto,x='Gender',y='Age',hue='Make');

# %%
plt.figure(figsize=(10,5))
sns.catplot(data=auto,x='Marital_status',y='Age',col='Make',hue='Gender',kind='swarm');

# %%
plt.figure(figsize=(10,5))
sns.catplot(data=auto,x='No_of_Dependents',y='Age',col='Make',hue='Marital_status',kind='swarm');

# %%
plt.figure(figsize=(10,5))
sns.catplot(data=auto,x='No_of_Dependents',y='Age',col='Make',hue='Marital_status',kind='swarm');

# %%
plt.figure(figsize=(10,5))
sns.catplot(data=auto,y='Age',x='Personal_loan',col='Make',hue='Gender',kind='swarm');

# %%
plt.figure(figsize=(10,5))
sns.catplot(data=auto,y='Age',x='Personal_loan',col='Make',hue='Marital_status',kind='swarm');

# %%
plt.figure(figsize=(10,5))
sns.catplot(data=auto,y='Age',x='House_loan',col='Make',hue='Gender',kind='swarm');

# %%
plt.figure(figsize=(10,5))
sns.catplot(data=auto,y='Age',x='House_loan',col='Make',hue='Marital_status',kind='swarm');

# %%
plt.figure(figsize=(10,5))
sns.catplot(data=auto,y='Price',x='Profession',col='Make',hue='Partner_working',kind='swarm');

# %%
plt.figure(figsize=(10,5))
sns.catplot(data=auto,y='Price',x='Profession',col='Make',hue='Gender',kind='swarm');

# %%
plt.figure(figsize=(30,5))
sns.catplot(data=auto,y='Salary',x='Gender',col='Make',hue='Marital_status',kind='swarm');

# %%
plt.figure(figsize=(30,5))
sns.catplot(data=auto,y='Salary',x='Gender',col='Make',hue='Age',kind='swarm');

# %%
plt.figure(figsize=(30,5))
sns.catplot(data=auto,y='Total_salary',x='Gender',col='Make',hue='Age',kind='swarm');

# %%
plt.figure(figsize=(15,7))
sns.boxplot(data=auto,x='Gender', y ='Price',hue='House_loan');

# %%
# Comment by Steve Roger
sns.countplot(data=auto,x='Gender', hue='Make');

# %%
# Comment by Ned Stark
plt.figure(figsize=(10,7))
sns.countplot(data=auto,x='Profession', hue = 'Make');

# %%
S = auto[auto['Profession']=='Salaried'] [auto['Gender']=='Male']

# %%
# Comment by Sheldon Cooper 
plt.xlabel('Salaried Male')
sns.countplot(data=S,x='Profession',hue='Make');

# %%
auto['Total Salary % Spent On Automobile'] = (auto['Price'] / auto['Total_salary'] * 100)

# %%
plt.figure(figsize=(15,7))
sns.catplot(data=auto,y='Total Salary % Spent On Automobile',x='Gender',kind='bar');

# %%
plt.figure(figsize=(15,7))
sns.catplot(data=auto,y='Total Salary % Spent On Automobile',x='Profession',kind='bar');

# %%
plt.figure(figsize=(15,7))
sns.catplot(data=auto,y='Total Salary % Spent On Automobile',x='Education',kind='bar');

# %%
plt.figure(figsize=(15,7))
sns.catplot(data=auto,y='Total Salary % Spent On Automobile',x='Marital_status',kind='bar');

# %%
plt.figure(figsize=(10,5))
sns.lineplot(data=auto,x='Price',y='Total_salary',hue='Partner_working',ci=False);

# %%
plt.figure(figsize=(15,7))
sns.catplot(data=auto,x='Marital_status',y='Total_salary',hue='Gender', col= 'Make', kind='box');

# %% [markdown]
# # PROBLEM 2

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
bank = pd.read_excel(r'C:\Users\ABC\Downloads\godigt_cc_data.xlsx')

# %%
bank
# Out:
#       userid              card_no  card_bin_no Issuer   card_type  \
# 0          1  4384 39XX XXXX XXXX       438439   Visa        edge
# 1          2  4377 48XX XXXX XXXX       437748   Visa  prosperity
# 2          3  4377 48XX XXXX XXXX       437748   Visa     rewards
# 3          4  4258 06XX XXXX XXXX       425806   Visa   indianoil
# 4          5  4377 48XX XXXX XXXX       437748   Visa        edge
# ...      ...                  ...          ...    ...         ...
# 8443    8444  4262 41XX XXXX XXXX       426241   Visa   chartered
# 8444    8445    37691 6XXXX XXXXX       376916   Amex   centurion
# 8445    8446  4375 51XX XXXX XXXX       437551   Visa     rewards
# 8446    8447  4477 47XX XXXX XXXX       447747   Visa   indianoil
# 8447    8448  4262 41XX XXXX XXXX       426241   Visa     rewards
#
#      card_source_date high_networth  active_30  active_60  active_90  ...  \
# 0          2019-09-29             B          0          1          1  ...
# ...

# %%
plt.figure(figsize=(20,7))
sns.countplot(data=bank,x='card_type');

# %%
plt.figure(figsize=(20,7))
sns.countplot(data=bank,x='high_networth');

# %%
plt.figure(figsize=(20,7))
sns.countplot(data=bank,x='Transactor_revolver');

# %%
plt.figure(figsize=(20,7))
sns.countplot(data=bank,x='Occupation_at_source');

# %%
plt.figure(figsize=(20,7))
sns.boxplot(data=bank,y='card_type', x='avg_spends_l3m');

# %%
plt.figure(figsize=(20,7))
sns.barplot(data=bank,x='card_type', y='avg_spends_l3m',hue='Transactor_revolver');

# %%
plt.figure(figsize=(20,7))
sns.barplot(data=bank,x='card_type', y='avg_spends_l3m',hue='Occupation_at_source');
